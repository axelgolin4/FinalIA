# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm

# %%
data = sns.load_dataset('diamonds')
data.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data.head(20)
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 0    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9    0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
# 10   0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 12   0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 13   0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 14   0.20    Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15   0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16   0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 17   0.30       Good     J     SI1   63.4   54.0    351  4.23  4.29  2.70
# 18   0.30       Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
# 19   0.30  Very Good     J     SI1   62.7   59.0    351  4.21  4.27  2.66

# %%
data[["cut", "color", "clarity"]].head(10)
# Out:
#          cut color clarity
# 0      Ideal     E     SI2
# 1    Premium     E     SI1
# 2       Good     E     VS1
# 3    Premium     I     VS2
# 4       Good     J     SI2
# 5  Very Good     J    VVS2
# 6  Very Good     I    VVS1
# 7  Very Good     H     SI1
# 8       Fair     E     VS2
# 9  Very Good     H     VS1

# %%
dx = data['cut']
dy = data['color']
dz = data['clarity']

# %%
data.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
# Matriz de correlacion
cormat = data.corr()

# %%
cormat
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
sns.heatmap(cormat, annot = True, square = True);

# %%
import numpy as np

# %%
data['Segmento'] = np.where(data.price >= 2000, 'alto',
                          np.where(data.price < 1000, 'bajo', 'moderado'))

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Segmento
# 0         bajo
# 1         bajo
# 2         bajo
# 3         bajo
# 4         bajo
# ...        ...
# 53935     alto
# 53936     alto
# 53937     alto
# 53938     alto
# 53939     alto
#
# [53940 rows x 11 columns]

# %%
data.groupby('Segmento')['price'].describe()
# Out:
#             count         mean          std     min      25%     50%     75%  \
# Segmento
# alto      29737.0  6319.262703  4003.535121  2000.0  3296.00  4964.0  8113.0
# bajo      14499.0   707.882061   161.534502   326.0   579.00   708.0   840.0
# moderado   9704.0  1438.140973   310.768967  1000.0  1140.75  1389.0  1721.0
#
#               max
# Segmento
# alto      18823.0
# bajo        999.0
# moderado   1999.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
col_a_escalar = ['price', 'x', 'y','carat','z']

# %%
datos_a_escalar = data[col_a_escalar]
datos_a_escalar
# Out:
#        price     x     y  carat     z
# 0        326  3.95  3.98   0.23  2.43
# 1        326  3.89  3.84   0.21  2.31
# 2        327  4.05  4.07   0.23  2.31
# 3        334  4.20  4.23   0.29  2.63
# 4        335  4.34  4.35   0.31  2.75
# ...      ...   ...   ...    ...   ...
# 53935   2757  5.75  5.76   0.72  3.50
# 53936   2757  5.69  5.75   0.72  3.61
# 53937   2757  5.66  5.68   0.70  3.56
# 53938   2757  6.15  6.12   0.86  3.74
# 53939   2757  5.83  5.87   0.75  3.64
#
# [53940 rows x 5 columns]

# %%
datos_copia_a_escalar = data.copy()
datos_copia_a_escalar
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       Segmento
# 0         bajo
# 1         bajo
# 2         bajo
# 3         bajo
# 4         bajo
# ...        ...
# 53935     alto
# 53936     alto
# 53937     alto
# 53938     alto
# 53939     alto
#
# [53940 rows x 11 columns]

# %%
datos_copia_a_escalar[col_a_escalar] = scaler.fit_transform(data[col_a_escalar])

# %%
cluster_cols = ['x', 'y']
datos_a_escalar[cluster_cols].head()
# Out:
#       x     y
# 0  3.95  3.98
# 1  3.89  3.84
# 2  4.05  4.07
# 3  4.20  4.23
# 4  4.34  4.35

# %%
datos_a_escalar.plot.scatter( x= 'x', y= 'y');

# %%
from sklearn.cluster import KMeans

# %%
# Parametros para el modelo
modelo = KMeans(n_clusters = 5, random_state = 42, n_init= 100)

# %%
modelo.fit(datos_copia_a_escalar[cluster_cols]
          )
# Out:
# KMeans(n_clusters=5, n_init=100, random_state=42)

# %%
datos_copia_a_escalar['Cluster2'] = modelo.predict(datos_copia_a_escalar[cluster_cols])

# %%
datos_copia_a_escalar.Segmento.value_counts()
# Out:
# alto        29737
# bajo        14499
# moderado     9704
# Name: Segmento, dtype: int64

# %%
datos_copia_a_escalar.Cluster2.value_counts()
# Out:
# 2    17539
# 0    15644
# 1    14138
# 3     6617
# 4        2
# Name: Cluster2, dtype: int64

# %%
# Marcadores
marcador = ['x', '*', '.', '|', '_']

# %%
import matplotlib.pyplot as plt
for segmento in range(5):
    temp = datos_copia_a_escalar[datos_copia_a_escalar.Cluster2 == segmento]
    plt.scatter(temp.x, temp.y, marker = marcador[segmento], label = 'Cluster '+ str(segmento))
plt.xlabel('x')
plt.ylabel('y')
plt.legend();

# %%
cluster_cols2 = ['x', 'y', 'carat', 'price']
datos_copia_a_escalar[cluster_cols2].head()
# Out:
#           x         y     carat     price
# 0 -1.587837 -1.536196 -1.198168 -0.904095
# 1 -1.641325 -1.658774 -1.240361 -0.904095
# 2 -1.498691 -1.457395 -1.198168 -0.903844
# 3 -1.364971 -1.317305 -1.071587 -0.902090
# 4 -1.240167 -1.212238 -1.029394 -0.901839

# %%
modelo2 = KMeans(n_clusters = 13, random_state = 42, n_init= 100)
modelo2.fit(datos_copia_a_escalar[cluster_cols2])
# Out:
# KMeans(n_clusters=13, n_init=100, random_state=42)

# %%
datos_copia_a_escalar['Cluster3'] = modelo2.predict(datos_copia_a_escalar[cluster_cols2])

# %%
datos_copia_a_escalar.head()
# Out:
#       carat      cut color clarity  depth  table     price         x  \
# 0 -1.198168    Ideal     E     SI2   61.5   55.0 -0.904095 -1.587837
# 1 -1.240361  Premium     E     SI1   59.8   61.0 -0.904095 -1.641325
# 2 -1.198168     Good     E     VS1   56.9   65.0 -0.903844 -1.498691
# 3 -1.071587  Premium     I     VS2   62.4   58.0 -0.902090 -1.364971
# 4 -1.029394     Good     J     SI2   63.3   58.0 -0.901839 -1.240167
#
#           y         z Segmento  Cluster2  Cluster3
# 0 -1.536196 -1.571129     bajo         2         1
# 1 -1.658774 -1.741175     bajo         2         1
# 2 -1.457395 -1.741175     bajo         2         1
# 3 -1.317305 -1.287720     bajo         2         1
# 4 -1.212238 -1.117674     bajo         2         1

# %%
datos_copia_a_escalar.Segmento.value_counts()
# Out:
# alto        29737
# bajo        14499
# moderado     9704
# Name: Segmento, dtype: int64

# %%
datos_copia_a_escalar.Cluster3.value_counts()
# Out:
# 1     10687
# 6      7250
# 12     6857
# 4      6808
# 7      6220
# 3      4291
# 0      3067
# 5      2631
# 11     2198
# 10     1669
# 8      1325
# 2       935
# 9         2
# Name: Cluster3, dtype: int64

# %%
marcador2 = ['x', '*', '.', '|', '_','s','^', 'o']

# %%
for segmento in range(8):
    temp = datos_copia_a_escalar[datos_copia_a_escalar.Cluster3 == segmento]
    plt.scatter(temp.x, temp.y, marker = marcador2[segmento], label = 'Cluster '+ str(segmento))
plt.xlabel('y')
plt.ylabel('x')
plt.legend();

# %%
from sklearn import decomposition

# %%
pca = decomposition.PCA(n_components = 2)
pca_res = pca.fit_transform(datos_a_escalar[cluster_cols2])

# %%
pca_res
# Out:
# array([[-3.60680042e+03, -1.24093427e+00],
#        [-3.60680047e+03, -1.38587774e+00],
#        [-3.60580037e+03, -1.11033783e+00],
#        ...,
#        [-1.17579968e+03,  3.23391306e-01],
#        [-1.17579944e+03,  9.97546773e-01],
#        [-1.17579959e+03,  5.83160184e-01]])

# %%
datos_copia_a_escalar['pc1'] = pca_res[:,0]
datos_copia_a_escalar['pc2'] = pca_res[:,1]

# %%
datos_copia_a_escalar
# Out:
#           carat        cut color clarity  depth  table     price         x  \
# 0     -1.198168      Ideal     E     SI2   61.5   55.0 -0.904095 -1.587837
# 1     -1.240361    Premium     E     SI1   59.8   61.0 -0.904095 -1.641325
# 2     -1.198168       Good     E     VS1   56.9   65.0 -0.903844 -1.498691
# 3     -1.071587    Premium     I     VS2   62.4   58.0 -0.902090 -1.364971
# 4     -1.029394       Good     J     SI2   63.3   58.0 -0.901839 -1.240167
# ...         ...        ...   ...     ...    ...    ...       ...       ...
# 53935 -0.164427      Ideal     D     SI1   60.8   57.0 -0.294731  0.016798
# 53936 -0.164427       Good     D     SI1   63.1   55.0 -0.294731 -0.036690
# 53937 -0.206621  Very Good     D     SI1   62.8   60.0 -0.294731 -0.063434
# 53938  0.130927    Premium     H     SI2   61.0   58.0 -0.294731  0.373383
# 53939 -0.101137      Ideal     D     SI2   62.2   55.0 -0.294731  0.088115
#
#               y         z Segmento  Cluster2  Cluster3          pc1       pc2
# 0     -1.536196 -1.571129     bajo         2         1 -3606.800418 -1.240934
# 1     -1.658774 -1.741175     bajo         2         1 -3606.800470 -1.385878
# 2     -1.457395 -1.741175     bajo         2         1 -3605.800371 -1.110338
# 3     -1.317305 -1.287720     bajo         2         1 -3598.800288 -0.885930
# 4     -1.212238 -1.117674     bajo         2         1 -3597.800221 -0.703145
# ...         ...       ...      ...       ...       ...          ...       ...
# 53935  0.022304 -0.054888     alto         1        12 -1175.799640  0.444679
# 53936  0.013548  0.100988     alto         1        12 -1175.799657  0.397936
# 53937 -0.047741  0.030135     alto         1        12 -1175.799684  0.323391
# 53938  0.337506  0.285204     alto         0         3 -1175.799436  0.997547
# 53939  0.118616  0.143499     alto         1        12 -1175.799590  0.583160
#
# [53940 rows x 15 columns]

# %%
modelo_ing2 = KMeans(n_clusters = 4, random_state = 42, n_init= 100)
modelo_ing2.fit(datos_copia_a_escalar[cluster_cols2])
datos_copia_a_escalar['Cluster4'] = modelo_ing2.predict(datos_copia_a_escalar[cluster_cols2])

# %%
marcador_ing2 = ['x', '*', '.', '|', '_','s','^', 'o']

# %%
for segmento in range(4):
    temp = datos_copia_a_escalar[datos_copia_a_escalar.Cluster4 == segmento]
    plt.scatter(temp.pc1, temp.pc2, marker = marcador_ing2[segmento], label = 'Cluster '+ str(segmento))
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend();

# %% [markdown]
# # KMEANS

# %%
cliente = data[['x', 'y', 'z']].copy()

# %%
# Crear modelo
km = KMeans(n_clusters=5, n_init=100, max_iter = 1000, init = 'random')

# %%
prediccion = km.fit_predict(cliente)

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from mpl_toolkits import mplot3d

# %%
silhouette_score(cliente, prediccion)
# Out:
# 0.5728051994892195

# %%
calinski_harabasz_score(cliente, prediccion)
# Out:
# 165025.8609720817

# %%
fig = plt.figure(figsize = (10,7))
ax = plt.axes(projection = '3d')
ax.scatter3D(cliente['x'], cliente['y'], cliente['z'], c =prediccion, cmap = 'tab10')
plt.title('kmean diamante')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()
